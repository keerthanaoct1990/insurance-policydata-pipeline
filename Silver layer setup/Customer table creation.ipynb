# %%
# %sql
create table if not exists silver.customer(
  customer_id int,
  first_name string,
  last_name string,
  email string,
  phone string,
  country string,
  city string,
  registration_date timestamp,
  date_of_birth timestamp,
  gender string,
  merged_timestamp timestamp
) using delta location "/mnt/bronze/customer"
