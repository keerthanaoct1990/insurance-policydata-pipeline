-- %%
%sql
create database if not exists silver

-- %%
create table if not exists silver.Agent(
agent_id integer,
agent_name string,
agent_email string,
agent_phone string,
branch_id integer,
create_timestamp timestamp,
merged_timestamp timestamp
) using delta location "/mnt/silver/Agent"
