# %%
from pyspark.sql.functions import lit

schema = "branch_id integer, branch_country string, branch_city string"
df = spark.read.parquet("/mnt/landing/BranchData", schema = schema)
df_with_flag = df.withColumn("merge_flag", lit(False))
df_with_flag.write.option("path","/mnt/bronze/Branch").mode("append").saveAsTable("bronze.Branch")

# %%
from datetime import datetime
def getFilepathwithDate(filePath):
    current_time = datetime.now().strftime("%Y-%m-%d")
    return f"{filePath}/{current_time}"

# %%
dbutils.fs.mv("/mnt/landing/BranchData", getFilepathwithDate("/mnt/processed/Branch"), recurse=True)
